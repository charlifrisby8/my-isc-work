# %% [markdown]
# # Exercise 1b: Label-based indexing

# %% [markdown]
# ## Aim: Learn how to index data arrays

# %% [markdown]
# Find the teaching resources here: https://tutorial.xarray.dev/fundamentals/02.1_indexing_Basic.html.

# %% [markdown]
# ### Issues Covered:
# - Indexing, using `.loc()`, `.isel()` and `.sel()`

# %% [markdown]
# Q1. Open the `'../data/xbhubo.pgc0apr.nc'` dataset and load it into an xarray `Dataset` called `ds`.
# (Hint: Don't forget to import any packages you need).
# This file is a model run for HadCM3 run as part of the RAPID study: https://catalogue.ceda.ac.uk/uuid/6bbab8394124b252f8b1b036f9eb6b6b/

# %%
import xarray as xr
ds = xr.open_dataset('../data/xbhubo.pgc0apr.nc')
ds
# Out:
# <xarray.Dataset> Size: 13MB
# Dimensions:      (longitude: 288, latitude: 144, depth: 20, t: 1,
#                   longitude_1: 288, latitude_1: 143)
# Coordinates:
#   * longitude    (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * latitude     (latitude) float32 576B -89.38 -88.12 -86.88 ... 88.12 89.38
#   * depth        (depth) float32 80B 5.0 15.0 25.0 ... 4.577e+03 5.192e+03
#   * t            (t) object 8B 1920-04-16 00:00:00
#   * longitude_1  (longitude_1) float32 1kB 0.625 1.875 3.125 ... 358.1 359.4
#   * latitude_1   (latitude_1) float32 572B -88.75 -87.5 -86.25 ... 87.5 88.75
# Data variables:
#     temp         (t, depth, latitude, longitude) float32 3MB ...
#     salinity     (t, depth, latitude, longitude) float32 3MB ...
#     ucurr        (t, depth, latitude_1, longitude_1) float32 3MB ...
#     vcurr        (t, depth, latitude_1, longitude_1) float32 3MB ...
# Attributes:
#     history:      Tue Sep 12 11:49:35 BST 2006 - CONVSH V1.91 16-February-2006
#     Conventions:  CF-1.0

# %% [markdown]
# Q2. Select a subset of the `temperature` array using label-based indexing to get data at the position [0,0,0].

# %%
temperature = ds["temp"]
temperature[0, 0, 0]
# Out:
# <xarray.DataArray 'temp' (longitude: 288)> Size: 1kB
# [288 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#     latitude   float32 4B -89.38
#     depth      float32 4B 5.0
#     t          object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495

# %% [markdown]
# Q3. Use `.loc` to find the temperature 5 meters below the sea surface in the South Atlantic where latitiude is -50.625 and longitude is 0.

# %%
temperature.loc[:, 5, -.625, 0]
# Out:
# <xarray.DataArray 'temp' (t: 1)> Size: 4B
# [1 values with dtype=float32]
# Coordinates:
#     longitude  float32 4B 0.0
#     latitude   float32 4B -0.625
#     depth      float32 4B 5.0
#   * t          (t) object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495

# %% [markdown]
# Q4. It's not ideal to have to keep track of which dimension is in which position. Instead, use `.isel` to use the dimension names to get the data in the same place: this is depth position 0, latitude position 31 and longitude position 0.

# %%
temperature.isel(depth=0, latitude=31, longitude=0)
# Out:
# <xarray.DataArray 'temp' (t: 1)> Size: 4B
# [1 values with dtype=float32]
# Coordinates:
#     longitude  float32 4B 0.0
#     latitude   float32 4B -50.62
#     depth      float32 4B 5.0
#   * t          (t) object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495

# %% [markdown]
# Q5. The previous method is still referring to a selection by integer position. Use `.sel` to give a labelled index with the named dimension to find the data at `lat=-78.5`, `lon=11.0`. You will need to pick a `method` too to select data with an inexact parameter.

# %%
temperature.sel(latitude=-78.5, longitude=11.0, method='none')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 temperature.sel(latitude=-78.5, longitude=11.0, method='none')
#
# File /opt/jaspy/lib/python3.12/site-packages/xarray/core/dataarray.py:1664, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1548 def sel(
#    1549     self,
#    1550     indexers: Mapping[Any, Any] | None = None,
#    (...)   1554     **indexers_kwargs: Any,
#    1555 ) -> Self:
#    1556     """Return a new DataArray whose data is given by selecting index
#    1557     labels along the specified dimension(s).
#    1558
#    (...)   1662     Dimensions without coordinates: points
#    1663     """
# -> 1664     ds = self._to_temp_dataset().sel(
#    1665         indexers=indexers,
#    1666         drop=drop,
#    1667         method=method,
#    1668         tolerance=tolerance,
#    1669         **indexers_kwargs,
#    1670     )
#    1671     return self._from_temp_dataset(ds)
#
# File /opt/jaspy/lib/python3.12/site-packages/xarray/core/dataset.py:2911, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2843 """Returns a new dataset with each array indexed by tick labels
#    2844 along the specified dimension(s).
#    2845
#    (...)   2908
#    2909 """
#    2910 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2911 query_results = map_index_queries(
#    2912     self, indexers=indexers, method=method, tolerance=tolerance
#    2913 )
#    2915 if drop:
#    2916     no_scalar_variables = {}
#
# File /opt/jaspy/lib/python3.12/site-packages/xarray/core/indexing.py:197, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     195         results.append(IndexSelResult(labels))
#     196     else:
# --> 197         results.append(index.sel(labels, **options))
#     199 merged = merge_sel_results(results)
#     201 # drop dimension coordinates found in dimension indexers
#     202 # (also drop multi-index if any)
#     203 # (.sel() already ensures alignment)
#
# File /opt/jaspy/lib/python3.12/site-packages/xarray/core/indexes.py:854, in PandasIndex.sel(self, labels, method, tolerance)
#     852     indexer = self.index.get_loc(label_value)
#     853 elif method is not None:
# --> 854     indexer = get_indexer_nd(self.index, label_array, method, tolerance)
#     855     if np.any(indexer < 0):
#     856         raise KeyError(f"not all values found in index {coord_name!r}")
#
# File /opt/jaspy/lib/python3.12/site-packages/xarray/core/indexes.py:630, in get_indexer_nd(index, labels, method, tolerance)
#     628 if flat_labels.dtype == "float16":
#     629     flat_labels = flat_labels.astype("float64")
# --> 630 flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
#     631 indexer = flat_indexer.reshape(labels.shape)
#     632 return indexer
#
# File /opt/jaspy/lib/python3.12/site-packages/pandas/core/indexes/base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3827 @final
#    3828 def get_indexer(
#    3829     self,
#    (...)   3833     tolerance=None,
#    3834 ) -> npt.NDArray[np.intp]:
#    3835     """
#    3836     Compute indexer and mask for new index given the current index.
#    3837
#    (...)   3883     and ``x`` is marked by -1, as it is not in ``index``.
#    3884     """
# -> 3885     method = clean_reindex_fill_method(method)
#    3886     orig_target = target
#    3887     target = self._maybe_cast_listlike_indexer(target)
#
# File /opt/jaspy/lib/python3.12/site-packages/pandas/core/missing.py:1076, in clean_reindex_fill_method(method)
#    1074 if method is None:
#    1075     return None
# -> 1076 return clean_fill_method(method, allow_nearest=True)
#
# File /opt/jaspy/lib/python3.12/site-packages/pandas/core/missing.py:177, in clean_fill_method(method, allow_nearest)
#     175     expecting = "pad (ffill), backfill (bfill) or nearest"
#     176 if method not in valid_methods:
# --> 177     raise ValueError(f"Invalid fill method. Expecting {expecting}. Got {method}")
#     178 return method
#
# ValueError: Invalid fill method. Expecting pad (ffill), backfill (bfill) or nearest. Got none

# %%
temperature.sel(latitude=-78.5, longitude=11.0, method='nearest')
# Out:
# <xarray.DataArray 'temp' (t: 1, depth: 20)> Size: 80B
# [20 values with dtype=float32]
# Coordinates:
#     longitude  float32 4B 11.25
#     latitude   float32 4B -78.12
#   * depth      (depth) float32 80B 5.0 15.0 25.0 ... 4.577e+03 5.192e+03
#   * t          (t) object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495
